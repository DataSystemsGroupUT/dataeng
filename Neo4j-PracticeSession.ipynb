# %% [markdown]
# # Introduction:
# ### Neo4J:
#    <a href="https://neo4j.com/">Neo4J</a>  is a graph database management system developed by Neo4j, Inc. Described by its developers as a native graph storage and processing. It is the most popular graph database according to DB-Engines ranking, and the 22nd most popular database overall.<br/>
# <img src="https://neo4j.com/wp-content/themes/neo4jweb/assets/images/neo4j-logo-2015.png">
#
#
# ### The Property Graph Model
# * In the property graph model, data is organized as nodes, relationships, and properties (data stored on the nodes or relationships).
#
# <img src= 'https://dist.neo4j.com/wp-content/uploads/property_graph_elements.jpg' width='600'>

# %% [markdown]
# ###  Cypher Query Language
#
# Cypher is Neo4j’s graph query language that allows users to store and retrieve data from the graph database. Cypher’s syntax provides a visual and logical way to match patterns of nodes and relationships in the graph.
# t is a declarative, SQL-inspired language for describing visual patterns in graphs using ASCII-Art syntax. It allows us to state what we want to select, insert, update, or delete from our graph data without a description of exactly how to do it.
#
# - First Steps with Cypher can be followed from this <a href='https://neo4j.com/developer/cypher/'>link </a>.

# %% [markdown]
# ## Pre-Lab:
# ### Installation
#
# 1. Install neo4j 3.5 Community Edition followin this <a href='https://neo4j.com/download-thanks/?edition=community&release=3.5.21&flavour=winzip&_ga=2.186751336.1137015944.1598288824-1813280835.1541597058'>link </a>
#
#
# Note:
#
#  * Click  <a href= 'https://neo4j.com/download-thanks-desktop/?edition=desktop&flavour=winstall64&release=1.3.4&offline=true'> here </a> to download the latest version of neo4j DeskTop for Windows.
#  * Follow the installation guide provided <a href= 'https://neo4j.com/download-thanks-desktop/?edition=desktop&flavour=winstall64&release=1.3.4&offline=true#installation-guide' > here </a> to download, install neo4j DEsktop on your Windows.
#  * make sure that you run Neo4j as a console application, use:
#      - <b> NEO4J_HOME\bin\neo4j console </b>
#      - Or install Neo4j as a service using: <b>NEO4J_HOME\bin\neo4j install-service </b>

# %% [markdown]
# 2. We can use the <b> "Neo4j Python" </b> driver which is officially supported by Neo4j and connects to the database using the binary protocol.
# It aims to be minimal, while being idiomatic to Python. <a href="https://neo4j.com/developer/python/">here</a>:
# ```
# pip install neo4j
# ```

# %% [markdown]
# ### ipython-cypher
# [ipython-cypher](https://github.com/versae/ipython-cypher) is another way to connect to a graph database in python. it uses <b> neo4jrestclient_ driver </b>, then issue Cypher commands within IPython or IPython Notebook.
# #### ipython-cypher install

# %%
! pip install ipython-cypher

# %% [markdown]
# #### Inside IPython, load the extension:

# %%
# %load_ext cypher

# %% [markdown]
# #### And then you are reay to go by using the <b>%cypher</b> or <b>%%cypher</b> line magic:
#
# you have to write down the connection url http://username:password@127.0.0.1:7474/db/data after the %%cypher to access your active DB using the neo4j http port (7474)

# %% [markdown]
# - '''%cypher''' is intended for one-line Cypher queries and '''%%cypher''' is intended for multi-line Cypher queries.
# - Placing "%%cypher" above a Cypher query will display that query's results.

# %% [markdown]
# ## Task 1: Movie-graph DB
# The Movie Graph is a mini graph application containing actors and directors that are related through the movies they've collaborated on.
#
# - The "Movies graph DB" example, is launched via the <font color='red'>:play movie-graph</font> command in your neo4j web UI/browser and contains a small graph of movies and people related to those movies as actors, directors, producers etc.
#
# <img src='https://storage.googleapis.com/kaggle-datasets-images/1365/2460/229bfb5d3dd1a49cc5ac899c45ca2213/dataset-original.png' width="400" height="100">

# %% [markdown]
# ### Perform some queries on the Graph database using Cypher Query Language.

# %% [markdown]
# #### Simplified Schema with labels of DB:
# - Run this command in your broswer **Call db.schema()**

# %% [markdown]
# <img src="schema1.png" alt="3" border="0"  width="400" height="100">

# %% [markdown]
# #### Get all people nodes in the Graph

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (n:Person) RETURN n
# Out:
# 133 rows affected.
# [[{'born': 1964, 'name': 'Keanu Reeves'}],
#  [{'born': 1967, 'name': 'Carrie-Anne Moss'}],
#  [{'born': 1961, 'name': 'Laurence Fishburne'}],
#  [{'born': 1960, 'name': 'Hugo Weaving'}],
#  [{'born': 1967, 'name': 'Lilly Wachowski'}],
#  [{'born': 1965, 'name': 'Lana Wachowski'}],
#  [{'born': 1952, 'name': 'Joel Silver'}],
#  [{'born': 1978, 'name': 'Emil Eifrem'}],
#  [{'born': 1975, 'name': 'Charlize Theron'}],
#  [{'born': 1940, 'name': 'Al Pacino'}],
#  [{'born': 1944, 'name': 'Taylor Hackford'}],
#  [{'born': 1962, 'name': 'Tom Cruise'}],
#  [{'born': 1937, 'name': 'Jack Nicholson'}],
#  [{'born': 1962, 'name': 'Demi Moore'}],
#  [{'born': 1958, 'name': 'Kevin Bacon'}],
#  [{'born': 1966, 'name': 'Kiefer Sutherland'}],
#  [{'born': 1971, 'name': 'Noah Wyle'}],
#  [{'born': 1968, 'name': 'Cuba Gooding Jr.'}],
#  [{'born': 1957, 'name': 'Kevin Pollak'}],
#  [{'born': 1943, 'name': 'J.T. Walsh'}],
#  [{'born': 1967, 'name': 'James Marshall'}],
#  [{'born': 1948, 'name': 'Christopher Guest'}],
#  [{'born': 1947, 'name': 'Rob Reiner'}],
#  [{'born': 1961, 'name': 'Aaron Sorkin'}],
#  [{'born': 1957, 'name': 'Kelly McGillis'}],
#  [{'born': 1959, 'name': 'Val Kilmer'}],
#  [{'born': 1962, 'name': 'Anthony Edwards'}],
#  [{'born': 1933, 'name': 'Tom Skerritt'}],
#  [{'born': 1961, 'name': 'Meg Ryan'}],
#  [{'born': 1944, 'name': 'Tony Scott'}],
#  [{'born': 1941, 'name': 'Jim Cash'}],
#  [{'born': 1969, 'name': 'Renee Zellweger'}],
#  [{'born': 1962, 'name': 'Kelly Preston'}],
#  [{'born': 1974, 'name': "Jerry O'Connell"}],
#  [{'born': 1970, 'name': 'Jay Mohr'}],
#  [{'born': 1961, 'name': 'Bonnie Hunt'}],
#  [{'born': 1971, 'name': 'Regina King'}],
#  [{'born': 1996, 'name': 'Jonathan Lipnicki'}],
#  [{'born': 1957, 'name': 'Cameron Crowe'}],
#  [{'born': 1970, 'name': 'River Phoenix'}],
#  [{'born': 1971, 'name': 'Corey Feldman'}],
#  [{'born': 1972, 'name': 'Wil Wheaton'}],
#  [{'born': 1966, 'name': 'John Cusack'}],
#  [{'born': 1942, 'name': 'Marshall Bell'}],
#  [{'born': 1963, 'name': 'Helen Hunt'}],
#  [{'born': 1963, 'name': 'Greg Kinnear'}],
#  [{'born': 1940, 'name': 'James L. Brooks'}],
#  [{'born': 1960, 'name': 'Annabella Sciorra'}],
#  [{'born': 1929, 'name': 'Max von Sydow'}],
#  [{'born': 1942, 'name': 'Werner Herzog'}],
#  [{'born': 1951, 'name': 'Robin Williams'}],
#  [{'born': 1956, 'name': 'Vincent Ward'}],
#  [{'born': 1970, 'name': 'Ethan Hawke'}],
#  [{'born': 1971, 'name': 'Rick Yune'}],
#  [{'born': 1940, 'name': 'James Cromwell'}],
#  [{'born': 1953, 'name': 'Scott Hicks'}],
#  [{'born': 1968, 'name': 'Parker Posey'}],
#  [{'born': 1973, 'name': 'Dave Chappelle'}],
#  [{'born': 1967, 'name': 'Steve Zahn'}],
#  [{'born': 1956, 'name': 'Tom Hanks'}],
#  [{'born': 1941, 'name': 'Nora Ephron'}],
#  [{'born': 1956, 'name': 'Rita Wilson'}],
#  [{'born': 1953, 'name': 'Bill Pullman'}],
#  [{'born': 1949, 'name': 'Victor Garber'}],
#  [{'born': 1962, 'name': "Rosie O'Donnell"}],
#  [{'born': 1950, 'name': 'John Patrick Stanley'}],
#  [{'born': 1956, 'name': 'Nathan Lane'}],
#  [{'born': 1948, 'name': 'Billy Crystal'}],
#  [{'born': 1956, 'name': 'Carrie Fisher'}],
#  [{'born': 1949, 'name': 'Bruno Kirby'}],
#  [{'born': 1977, 'name': 'Liv Tyler'}],
#  [{'born': 1970, 'name': 'Brooke Langton'}],
#  [{'born': 1930, 'name': 'Gene Hackman'}],
#  [{'born': 1968, 'name': 'Orlando Jones'}],
#  [{'born': 1950, 'name': 'Howard Deutch'}],
#  [{'born': 1974, 'name': 'Christian Bale'}],
#  [{'born': 1954, 'name': 'Zach Grenier'}],
#  [{'born': 1931, 'name': 'Mike Nichols'}],
#  [{'born': 1930, 'name': 'Richard Harris'}],
#  [{'born': 1930, 'name': 'Clint Eastwood'}],
#  [{'born': 1947, 'name': 'Takeshi Kitano'}],
#  [{'born': 1968, 'name': 'Dina Meyer'}],
#  [{'born': 1958, 'name': 'Ice-T'}],
#  [{'born': 1953, 'name': 'Robert Longo'}],
#  [{'born': 1966, 'name': 'Halle Berry'}],
#  [{'born': 1949, 'name': 'Jim Broadbent'}],
#  [{'born': 1965, 'name': 'Tom Tykwer'}],
#  [{'born': 1969, 'name': 'David Mitchell'}],
#  [{'born': 1961, 'name': 'Stefan Arndt'}],
#  [{'born': 1939, 'name': 'Ian McKellen'}],
#  [{'born': 1976, 'name': 'Audrey Tautou'}],
#  [{'born': 1971, 'name': 'Paul Bettany'}],
#  [{'born': 1954, 'name': 'Ron Howard'}],
#  [{'born': 1981, 'name': 'Natalie Portman'}],
#  [{'born': 1946, 'name': 'Stephen Rea'}],
#  [{'born': 1940, 'name': 'John Hurt'}],
#  [{'born': 1967, 'name': 'Ben Miles'}],
#  [{'born': 1985, 'name': 'Emile Hirsch'}],
#  [{'born': 1960, 'name': 'John Goodman'}],
#  [{'born': 1946, 'name': 'Susan Sarandon'}],
#  [{'born': 1966, 'name': 'Matthew Fox'}],
#  [{'born': 1980, 'name': 'Christina Ricci'}],
#  [{'born': 1982, 'name': 'Rain'}],
#  [{'name': 'Naomie Harris'}],
#  [{'born': 1957, 'name': 'Michael Clarke Duncan'}],
#  [{'born': 1953, 'name': 'David Morse'}],
#  [{'born': 1968, 'name': 'Sam Rockwell'}],
#  [{'born': 1955, 'name': 'Gary Sinise'}],
#  [{'born': 1959, 'name': 'Patricia Clarkson'}],
#  [{'born': 1959, 'name': 'Frank Darabont'}],
#  [{'born': 1938, 'name': 'Frank Langella'}],
#  [{'born': 1969, 'name': 'Michael Sheen'}],
#  [{'born': 1960, 'name': 'Oliver Platt'}],
#  [{'born': 1944, 'name': 'Danny DeVito'}],
#  [{'born': 1965, 'name': 'John C. Reilly'}],
#  [{'born': 1950, 'name': 'Ed Harris'}],
#  [{'born': 1955, 'name': 'Bill Paxton'}],
#  [{'born': 1967, 'name': 'Philip Seymour Hoffman'}],
#  [{'born': 1943, 'name': 'Jan de Bont'}],
#  [{'born': 1951, 'name': 'Robert Zemeckis'}],
#  [{'born': 1932, 'name': 'Milos Forman'}],
#  [{'born': 1946, 'name': 'Diane Keaton'}],
#  [{'born': 1949, 'name': 'Nancy Meyers'}],
#  [{'born': 1958, 'name': 'Chris Columbus'}],
#  [{'born': 1967, 'name': 'Julia Roberts'}],
#  [{'born': 1954, 'name': 'Madonna'}],
#  [{'born': 1956, 'name': 'Geena Davis'}],
#  [{'born': 1963, 'name': 'Lori Petty'}],
#  [{'born': 1943, 'name': 'Penny Marshall'}],
#  [{'name': 'Paul Blythe'}],
#  [{'name': 'Angela Scope'}],
#  [{'name': 'Jessica Thompson'}],
#  [{'name': 'James Thompson'}]]

# %% [markdown]
# #### Get the label of those nodes

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (n:Person) RETURN LABELS(n)
# Out:
# 133 rows affected.
# [[['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']],
#  [['Person']]]

# %% [markdown]
# #### Get the node of "Tom Hanks"

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (n:Person {name:"Tom Hanks"}) RETURN n
# Out:
# 1 rows affected.
# [[{'born': 1956, 'name': 'Tom Hanks'}]]

# %% [markdown]
# ###  Projections
#
# #### Get the title, release_year of movies

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)
# RETURN m.title, m.released
# Out:
# 38 rows affected.
# [['The Matrix', 1999],
#  ['The Matrix Reloaded', 2003],
#  ['The Matrix Revolutions', 2003],
#  ["The Devil's Advocate", 1997],
#  ['A Few Good Men', 1992],
#  ['Top Gun', 1986],
#  ['Jerry Maguire', 2000],
#  ['Stand By Me', 1986],
#  ['As Good as It Gets', 1997],
#  ['What Dreams May Come', 1998],
#  ['Snow Falling on Cedars', 1999],
#  ["You've Got Mail", 1998],
#  ['Sleepless in Seattle', 1993],
#  ['Joe Versus the Volcano', 1990],
#  ['When Harry Met Sally', 1998],
#  ['That Thing You Do', 1996],
#  ['The Replacements', 2000],
#  ['RescueDawn', 2006],
#  ['The Birdcage', 1996],
#  ['Unforgiven', 1992],
#  ['Johnny Mnemonic', 1995],
#  ['Cloud Atlas', 2012],
#  ['The Da Vinci Code', 2006],
#  ['V for Vendetta', 2006],
#  ['Speed Racer', 2008],
#  ['Ninja Assassin', 2009],
#  ['The Green Mile', 1999],
#  ['Frost/Nixon', 2008],
#  ['Hoffa', 1992],
#  ['Apollo 13', 1995],
#  ['Twister', 1996],
#  ['Cast Away', 2000],
#  ["One Flew Over the Cuckoo's Nest", 1975],
#  ["Something's Gotta Give", 2003],
#  ['Bicentennial Man', 1999],
#  ["Charlie Wilson's War", 2007],
#  ['The Polar Express', 2004],
#  ['A League of Their Own', 1992]]

# %% [markdown]
# ### Matching By a relationship (Querying)
# #### Get the people and their relationships to movies (regardless of the type of the relationship)

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (p:Person) -->(m:Movie)
# RETURN * LIMIT 10
# Out:
# 10 rows affected.
# [[{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1978, 'name': 'Emil Eifrem'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1952, 'name': 'Joel Silver'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1965, 'name': 'Lana Wachowski'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1967, 'name': 'Lilly Wachowski'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1960, 'name': 'Hugo Weaving'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1961, 'name': 'Laurence Fishburne'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1967, 'name': 'Carrie-Anne Moss'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1964, 'name': 'Keanu Reeves'}],
#  [{'tagline': 'Free your mind',
#    'title': 'The Matrix Reloaded',
#    'released': 2003},
#   {'born': 1952, 'name': 'Joel Silver'}],
#  [{'tagline': 'Free your mind',
#    'title': 'The Matrix Reloaded',
#    'released': 2003},
#   {'born': 1965, 'name': 'Lana Wachowski'}]]

# %% [markdown]
# #### Get all the movies and people who acted in those movies

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (p:Person) -[:ACTED_IN]->(m:Movie)
# RETURN * LIMIT 10
# Out:
# 10 rows affected.
# [[{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1978, 'name': 'Emil Eifrem'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1960, 'name': 'Hugo Weaving'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1961, 'name': 'Laurence Fishburne'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1967, 'name': 'Carrie-Anne Moss'}],
#  [{'tagline': 'Welcome to the Real World',
#    'title': 'The Matrix',
#    'released': 1999},
#   {'born': 1964, 'name': 'Keanu Reeves'}],
#  [{'tagline': 'Free your mind',
#    'title': 'The Matrix Reloaded',
#    'released': 2003},
#   {'born': 1960, 'name': 'Hugo Weaving'}],
#  [{'tagline': 'Free your mind',
#    'title': 'The Matrix Reloaded',
#    'released': 2003},
#   {'born': 1961, 'name': 'Laurence Fishburne'}],
#  [{'tagline': 'Free your mind',
#    'title': 'The Matrix Reloaded',
#    'released': 2003},
#   {'born': 1967, 'name': 'Carrie-Anne Moss'}],
#  [{'tagline': 'Free your mind',
#    'title': 'The Matrix Reloaded',
#    'released': 2003},
#   {'born': 1964, 'name': 'Keanu Reeves'}],
#  [{'tagline': 'Everything that has a beginning has an end',
#    'title': 'The Matrix Revolutions',
#    'released': 2003},
#   {'born': 1960, 'name': 'Hugo Weaving'}]]

# %% [markdown]
# ### Filtering (WHERE Clause)
#
# ####  What were the movies that "Tom Hanks" acted in

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (p:Person) -[:ACTED_IN]->(m:Movie)
# WHERE p.name="Tom Hanks"
# RETURN m.title
# Out:
# 12 rows affected.
# [['Apollo 13'],
#  ["You've Got Mail"],
#  ['A League of Their Own'],
#  ['Joe Versus the Volcano'],
#  ['That Thing You Do'],
#  ['The Da Vinci Code'],
#  ['Cloud Atlas'],
#  ['Cast Away'],
#  ['The Green Mile'],
#  ['Sleepless in Seattle'],
#  ['The Polar Express'],
#  ["Charlie Wilson's War"]]

# %% [markdown]
# ####  What were the movies released in 1990s

# %%
# %%cypher http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)
# WHERE m.released>1990 AND m.released<2000
# RETURN m.title, m.released
# Out:
# 19 rows affected.
# [['The Matrix', 1999],
#  ["The Devil's Advocate", 1997],
#  ['A Few Good Men', 1992],
#  ['As Good as It Gets', 1997],
#  ['What Dreams May Come', 1998],
#  ['Snow Falling on Cedars', 1999],
#  ["You've Got Mail", 1998],
#  ['Sleepless in Seattle', 1993],
#  ['When Harry Met Sally', 1998],
#  ['That Thing You Do', 1996],
#  ['The Birdcage', 1996],
#  ['Unforgiven', 1992],
#  ['Johnny Mnemonic', 1995],
#  ['The Green Mile', 1999],
#  ['Hoffa', 1992],
#  ['Apollo 13', 1995],
#  ['Twister', 1996],
#  ['Bicentennial Man', 1999],
#  ['A League of Their Own', 1992]]

# %% [markdown]
# #### Who Directed "Cloud Atlas"  movie?

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (p:Person) -[:DIRECTED]->(m:Movie)
# WHERE m.title="Cloud Atlas"
# RETURN p.name
# Out:
# 3 rows affected.
# [['Tom Tykwer'], ['Lana Wachowski'], ['Lilly Wachowski']]

# %% [markdown]
# #### Get Actors and movies , but skip who also Directed Movie at all

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (p:Person)-[:ACTED_IN]->(m)
# WHERE (p)-[:DIRECTED]->()
# RETURN DISTINCT p.name
# Out:
# 5 rows affected.
# [['James Marshall'],
#  ['Werner Herzog'],
#  ['Tom Hanks'],
#  ['Clint Eastwood'],
#  ['Danny DeVito']]

# %% [markdown]
# ###  Unique Results (Distinct)
# #### Get DISTINCT Labels in your GraphDB

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (n)
# RETURN DISTINCT labels(n) AS Labels
# Out:
# 2 rows affected.
# [[['Movie']], [['Person']]]

# %% [markdown]
# ####  Get Tom Hanks Co-Actors (and in which movies)

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (:Person{name:"Tom Hanks"}) -[:ACTED_IN]->(m:Movie)<-[:ACTED_IN]-(coActors)
# RETURN coActors.name, m.title
# Out:
# 39 rows affected.
# [['Ed Harris', 'Apollo 13'],
#  ['Gary Sinise', 'Apollo 13'],
#  ['Kevin Bacon', 'Apollo 13'],
#  ['Bill Paxton', 'Apollo 13'],
#  ['Parker Posey', "You've Got Mail"],
#  ['Greg Kinnear', "You've Got Mail"],
#  ['Meg Ryan', "You've Got Mail"],
#  ['Steve Zahn', "You've Got Mail"],
#  ['Dave Chappelle', "You've Got Mail"],
#  ['Madonna', 'A League of Their Own'],
#  ["Rosie O'Donnell", 'A League of Their Own'],
#  ['Geena Davis', 'A League of Their Own'],
#  ['Bill Paxton', 'A League of Their Own'],
#  ['Lori Petty', 'A League of Their Own'],
#  ['Nathan Lane', 'Joe Versus the Volcano'],
#  ['Meg Ryan', 'Joe Versus the Volcano'],
#  ['Liv Tyler', 'That Thing You Do'],
#  ['Charlize Theron', 'That Thing You Do'],
#  ['Ian McKellen', 'The Da Vinci Code'],
#  ['Audrey Tautou', 'The Da Vinci Code'],
#  ['Paul Bettany', 'The Da Vinci Code'],
#  ['Jim Broadbent', 'Cloud Atlas'],
#  ['Halle Berry', 'Cloud Atlas'],
#  ['Hugo Weaving', 'Cloud Atlas'],
#  ['Helen Hunt', 'Cast Away'],
#  ['Sam Rockwell', 'The Green Mile'],
#  ['Bonnie Hunt', 'The Green Mile'],
#  ['Patricia Clarkson', 'The Green Mile'],
#  ['James Cromwell', 'The Green Mile'],
#  ['Michael Clarke Duncan', 'The Green Mile'],
#  ['David Morse', 'The Green Mile'],
#  ['Gary Sinise', 'The Green Mile'],
#  ['Meg Ryan', 'Sleepless in Seattle'],
#  ['Victor Garber', 'Sleepless in Seattle'],
#  ['Bill Pullman', 'Sleepless in Seattle'],
#  ['Rita Wilson', 'Sleepless in Seattle'],
#  ["Rosie O'Donnell", 'Sleepless in Seattle'],
#  ['Julia Roberts', "Charlie Wilson's War"],
#  ['Philip Seymour Hoffman', "Charlie Wilson's War"]]

# %% [markdown]
# #### How people are related to (Acted_IN, Directed, Produced, etc) to the "Cloud Atlas" movie?

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
#
# MATCH (people:Person)-[relatedTo]-(:Movie {title: "Cloud Atlas"})
# RETURN people.name, Type(relatedTo), relatedTo As roles_if_Actor
# Out:
# 10 rows affected.
# [['Tom Hanks',
#   'ACTED_IN',
#   {'roles': ['Zachry', 'Dr. Henry Goose', 'Isaac Sachs', 'Dermot Hoggins']}],
#  ['Jim Broadbent',
#   'ACTED_IN',
#   {'roles': ['Vyvyan Ayrs', 'Captain Molyneux', 'Timothy Cavendish']}],
#  ['David Mitchell', 'WROTE', {}],
#  ['Tom Tykwer', 'DIRECTED', {}],
#  ['Lana Wachowski', 'DIRECTED', {}],
#  ['Stefan Arndt', 'PRODUCED', {}],
#  ['Jessica Thompson',
#   'REVIEWED',
#   {'summary': 'An amazing journey', 'rating': 95}],
#  ['Halle Berry',
#   'ACTED_IN',
#   {'roles': ['Luisa Rey', 'Jocasta Ayrs', 'Ovid', 'Meronym']}],
#  ['Hugo Weaving',
#   'ACTED_IN',
#   {'roles': ['Bill Smoke',
#     'Haskell Moore',
#     'Tadeusz Kesselring',
#     'Nurse Noakes',
#     'Boardman Mephi',
#     'Old Georgie']}],
#  ['Lilly Wachowski', 'DIRECTED', {}]]

# %% [markdown]
#  #### Get the movies that "Tom Hanks" Acted in and also Directed

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (tom:Person{name:"Tom Hanks"}) -[:ACTED_IN]->(m:Movie) <-[:DIRECTED]-(tom)
# RETURN m.title
# Out:
# 1 rows affected.
# [['That Thing You Do']]

# %% [markdown]
# ###  LIMIT&&SKIP
# ####  Get the movies that "Tom Hanks" Acted, skip the first movie and get the next following two ones.

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (:Person{name:"Tom Hanks"}) -[:ACTED_IN]->(m)
# RETURN m.title
# SKIP 2
# LIMIT 3
# Out:
# 3 rows affected.
# [['A League of Their Own'], ['Joe Versus the Volcano'], ['That Thing You Do']]

# %% [markdown]
# ### ORDER BY
# #### Get the movies that "Tom Hanks" Acted ordered by the title

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (:Person{name:"Tom Hanks"}) -[:ACTED_IN]->(m:Movie)
# RETURN m.title
# ORDER BY m.title
# Out:
# 12 rows affected.
# [['A League of Their Own'],
#  ['Apollo 13'],
#  ['Cast Away'],
#  ["Charlie Wilson's War"],
#  ['Cloud Atlas'],
#  ['Joe Versus the Volcano'],
#  ['Sleepless in Seattle'],
#  ['That Thing You Do'],
#  ['The Da Vinci Code'],
#  ['The Green Mile'],
#  ['The Polar Express'],
#  ["You've Got Mail"]]

# %% [markdown]
# ### Cypher Aggregation Functions
# #### Get the count of Movies acted by "Tom Hanks"

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (:Person{name:"Tom Hanks"}) -[:ACTED_IN]->(m:Movie)
# RETURN COUNT(*) As TomCount
# Out:
# 1 rows affected.
# [[12]]

# %% [markdown]
# ####  Get the top 10 profilic actors (Actors who made the most apperances in movies)

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (a:Person)-[:ACTED_IN]->(m:Movie)
# RETURN a, count(*) AS appearances
# ORDER BY appearances DESC LIMIT 10
# Out:
# 10 rows affected.
# [[{'born': 1956, 'name': 'Tom Hanks'}, 12],
#  [{'born': 1964, 'name': 'Keanu Reeves'}, 7],
#  [{'born': 1960, 'name': 'Hugo Weaving'}, 5],
#  [{'born': 1961, 'name': 'Meg Ryan'}, 5],
#  [{'born': 1937, 'name': 'Jack Nicholson'}, 5],
#  [{'born': 1968, 'name': 'Cuba Gooding Jr.'}, 4],
#  [{'born': 1961, 'name': 'Laurence Fishburne'}, 3],
#  [{'born': 1962, 'name': 'Tom Cruise'}, 3],
#  [{'born': 1963, 'name': 'Helen Hunt'}, 3],
#  [{'born': 1958, 'name': 'Kevin Bacon'}, 3]]

# %% [markdown]
# #### What is the released year of the most recent movie acted by "Tom Hanks"

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (:Person{name:"Tom Hanks"}) -[:ACTED_IN]->(m:Movie)
# RETURN MAX(m.released)
# Out:
# 1 rows affected.
# [[2012]]

# %% [markdown]
# #### For each movie, get the list of actors (cast), and their count.

# %%
# %%cypher http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (m:Movie)<-[:ACTED_IN]-(a:Person)
# RETURN m.title AS movie, collect(a.name) AS cast, count(*) AS actors
# Out:
# 38 rows affected.
# [['The Matrix',
#   ['Emil Eifrem',
#    'Hugo Weaving',
#    'Laurence Fishburne',
#    'Carrie-Anne Moss',
#    'Keanu Reeves'],
#   5],
#  ['The Matrix Reloaded',
#   ['Hugo Weaving', 'Laurence Fishburne', 'Carrie-Anne Moss', 'Keanu Reeves'],
#   4],
#  ['The Matrix Revolutions',
#   ['Hugo Weaving', 'Laurence Fishburne', 'Carrie-Anne Moss', 'Keanu Reeves'],
#   4],
#  ["The Devil's Advocate", ['Al Pacino', 'Charlize Theron', 'Keanu Reeves'], 3],
#  ['A Few Good Men',
#   ['James Marshall',
#    'Kevin Pollak',
#    'J.T. Walsh',
#    'Aaron Sorkin',
#    'Cuba Gooding Jr.',
#    'Christopher Guest',
#    'Noah Wyle',
#    'Kiefer Sutherland',
#    'Kevin Bacon',
#    'Demi Moore',
#    'Jack Nicholson',
#    'Tom Cruise'],
#   12],
#  ['Top Gun',
#   ['Val Kilmer',
#    'Meg Ryan',
#    'Tom Skerritt',
#    'Kelly McGillis',
#    'Tom Cruise',
#    'Anthony Edwards'],
#   6],
#  ['Jerry Maguire',
#   ["Jerry O'Connell",
#    'Bonnie Hunt',
#    'Jay Mohr',
#    'Cuba Gooding Jr.',
#    'Jonathan Lipnicki',
#    'Renee Zellweger',
#    'Kelly Preston',
#    'Regina King',
#    'Tom Cruise'],
#   9],
#  ['Stand By Me',
#   ["Jerry O'Connell",
#    'River Phoenix',
#    'Marshall Bell',
#    'Wil Wheaton',
#    'Kiefer Sutherland',
#    'John Cusack',
#    'Corey Feldman'],
#   7],
#  ['As Good as It Gets',
#   ['Helen Hunt', 'Jack Nicholson', 'Cuba Gooding Jr.', 'Greg Kinnear'],
#   4],
#  ['What Dreams May Come',
#   ['Robin Williams',
#    'Cuba Gooding Jr.',
#    'Max von Sydow',
#    'Werner Herzog',
#    'Annabella Sciorra'],
#   5],
#  ['Snow Falling on Cedars',
#   ['Ethan Hawke', 'Rick Yune', 'Max von Sydow', 'James Cromwell'],
#   4],
#  ["You've Got Mail",
#   ['Tom Hanks',
#    'Parker Posey',
#    'Greg Kinnear',
#    'Meg Ryan',
#    'Steve Zahn',
#    'Dave Chappelle'],
#   6],
#  ['Sleepless in Seattle',
#   ['Meg Ryan',
#    'Victor Garber',
#    'Tom Hanks',
#    'Bill Pullman',
#    'Rita Wilson',
#    "Rosie O'Donnell"],
#   6],
#  ['Joe Versus the Volcano', ['Tom Hanks', 'Nathan Lane', 'Meg Ryan'], 3],
#  ['When Harry Met Sally',
#   ['Carrie Fisher', 'Billy Crystal', 'Bruno Kirby', 'Meg Ryan'],
#   4],
#  ['That Thing You Do', ['Tom Hanks', 'Liv Tyler', 'Charlize Theron'], 3],
#  ['The Replacements',
#   ['Brooke Langton', 'Keanu Reeves', 'Orlando Jones', 'Gene Hackman'],
#   4],
#  ['RescueDawn',
#   ['Zach Grenier', 'Steve Zahn', 'Christian Bale', 'Marshall Bell'],
#   4],
#  ['The Birdcage', ['Robin Williams', 'Nathan Lane', 'Gene Hackman'], 3],
#  ['Unforgiven', ['Clint Eastwood', 'Gene Hackman', 'Richard Harris'], 3],
#  ['Johnny Mnemonic',
#   ['Ice-T', 'Dina Meyer', 'Keanu Reeves', 'Takeshi Kitano'],
#   4],
#  ['Cloud Atlas',
#   ['Tom Hanks', 'Jim Broadbent', 'Halle Berry', 'Hugo Weaving'],
#   4],
#  ['The Da Vinci Code',
#   ['Tom Hanks', 'Ian McKellen', 'Audrey Tautou', 'Paul Bettany'],
#   4],
#  ['V for Vendetta',
#   ['John Hurt', 'Stephen Rea', 'Natalie Portman', 'Hugo Weaving', 'Ben Miles'],
#   5],
#  ['Speed Racer',
#   ['Emile Hirsch',
#    'Rain',
#    'Christina Ricci',
#    'Ben Miles',
#    'Susan Sarandon',
#    'John Goodman',
#    'Matthew Fox'],
#   7],
#  ['Ninja Assassin', ['Rain', 'Ben Miles', 'Rick Yune', 'Naomie Harris'], 4],
#  ['The Green Mile',
#   ['Sam Rockwell',
#    'Bonnie Hunt',
#    'Patricia Clarkson',
#    'James Cromwell',
#    'Tom Hanks',
#    'Michael Clarke Duncan',
#    'David Morse',
#    'Gary Sinise'],
#   8],
#  ['Frost/Nixon',
#   ['Sam Rockwell',
#    'Michael Sheen',
#    'Frank Langella',
#    'Oliver Platt',
#    'Kevin Bacon'],
#   5],
#  ['Hoffa',
#   ['John C. Reilly', 'Danny DeVito', 'J.T. Walsh', 'Jack Nicholson'],
#   4],
#  ['Apollo 13',
#   ['Tom Hanks', 'Ed Harris', 'Gary Sinise', 'Kevin Bacon', 'Bill Paxton'],
#   5],
#  ['Twister',
#   ['Helen Hunt', 'Bill Paxton', 'Philip Seymour Hoffman', 'Zach Grenier'],
#   4],
#  ['Cast Away', ['Helen Hunt', 'Tom Hanks'], 2],
#  ["One Flew Over the Cuckoo's Nest", ['Danny DeVito', 'Jack Nicholson'], 2],
#  ["Something's Gotta Give",
#   ['Keanu Reeves', 'Diane Keaton', 'Jack Nicholson'],
#   3],
#  ['Bicentennial Man', ['Robin Williams', 'Oliver Platt'], 2],
#  ["Charlie Wilson's War",
#   ['Julia Roberts', 'Tom Hanks', 'Philip Seymour Hoffman'],
#   3],
#  ['The Polar Express', ['Tom Hanks'], 1],
#  ['A League of Their Own',
#   ['Tom Hanks',
#    'Madonna',
#    "Rosie O'Donnell",
#    'Geena Davis',
#    'Bill Paxton',
#    'Lori Petty'],
#   6]]

# %% [markdown]
# #### Get the first 3 movies of each actor

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (n:Person)-[:ACTED_IN]-(m)
# Return n.name ,
# collect(m.title)[..3] as movies
# Out:
# 102 rows affected.
# [['Keanu Reeves',
#   ["Something's Gotta Give", 'The Replacements', 'Johnny Mnemonic']],
#  ['Carrie-Anne Moss',
#   ['The Matrix Revolutions', 'The Matrix Reloaded', 'The Matrix']],
#  ['Laurence Fishburne',
#   ['The Matrix Revolutions', 'The Matrix Reloaded', 'The Matrix']],
#  ['Hugo Weaving', ['Cloud Atlas', 'V for Vendetta', 'The Matrix Revolutions']],
#  ['Emil Eifrem', ['The Matrix']],
#  ['Charlize Theron', ['That Thing You Do', "The Devil's Advocate"]],
#  ['Al Pacino', ["The Devil's Advocate"]],
#  ['Tom Cruise', ['Jerry Maguire', 'Top Gun', 'A Few Good Men']],
#  ['Jack Nicholson',
#   ['As Good as It Gets',
#    "One Flew Over the Cuckoo's Nest",
#    "Something's Gotta Give"]],
#  ['Demi Moore', ['A Few Good Men']],
#  ['Kevin Bacon', ['Apollo 13', 'Frost/Nixon', 'A Few Good Men']],
#  ['Kiefer Sutherland', ['Stand By Me', 'A Few Good Men']],
#  ['Noah Wyle', ['A Few Good Men']],
#  ['Cuba Gooding Jr.',
#   ['What Dreams May Come', 'Jerry Maguire', 'As Good as It Gets']],
#  ['Kevin Pollak', ['A Few Good Men']],
#  ['J.T. Walsh', ['Hoffa', 'A Few Good Men']],
#  ['James Marshall', ['A Few Good Men']],
#  ['Christopher Guest', ['A Few Good Men']],
#  ['Aaron Sorkin', ['A Few Good Men']],
#  ['Kelly McGillis', ['Top Gun']],
#  ['Val Kilmer', ['Top Gun']],
#  ['Anthony Edwards', ['Top Gun']],
#  ['Tom Skerritt', ['Top Gun']],
#  ['Meg Ryan', ['Sleepless in Seattle', "You've Got Mail", 'Top Gun']],
#  ['Renee Zellweger', ['Jerry Maguire']],
#  ['Kelly Preston', ['Jerry Maguire']],
#  ["Jerry O'Connell", ['Jerry Maguire', 'Stand By Me']],
#  ['Jay Mohr', ['Jerry Maguire']],
#  ['Bonnie Hunt', ['The Green Mile', 'Jerry Maguire']],
#  ['Regina King', ['Jerry Maguire']],
#  ['Jonathan Lipnicki', ['Jerry Maguire']],
#  ['River Phoenix', ['Stand By Me']],
#  ['Corey Feldman', ['Stand By Me']],
#  ['Wil Wheaton', ['Stand By Me']],
#  ['John Cusack', ['Stand By Me']],
#  ['Marshall Bell', ['Stand By Me', 'RescueDawn']],
#  ['Helen Hunt', ['As Good as It Gets', 'Cast Away', 'Twister']],
#  ['Greg Kinnear', ["You've Got Mail", 'As Good as It Gets']],
#  ['Annabella Sciorra', ['What Dreams May Come']],
#  ['Max von Sydow', ['What Dreams May Come', 'Snow Falling on Cedars']],
#  ['Werner Herzog', ['What Dreams May Come']],
#  ['Robin Williams',
#   ['What Dreams May Come', 'Bicentennial Man', 'The Birdcage']],
#  ['Ethan Hawke', ['Snow Falling on Cedars']],
#  ['Rick Yune', ['Ninja Assassin', 'Snow Falling on Cedars']],
#  ['James Cromwell', ['The Green Mile', 'Snow Falling on Cedars']],
#  ['Parker Posey', ["You've Got Mail"]],
#  ['Dave Chappelle', ["You've Got Mail"]],
#  ['Steve Zahn', ['RescueDawn', "You've Got Mail"]],
#  ['Tom Hanks', ['Apollo 13', "You've Got Mail", 'A League of Their Own']],
#  ['Rita Wilson', ['Sleepless in Seattle']],
#  ['Bill Pullman', ['Sleepless in Seattle']],
#  ['Victor Garber', ['Sleepless in Seattle']],
#  ["Rosie O'Donnell", ['A League of Their Own', 'Sleepless in Seattle']],
#  ['Nathan Lane', ['Joe Versus the Volcano', 'The Birdcage']],
#  ['Billy Crystal', ['When Harry Met Sally']],
#  ['Carrie Fisher', ['When Harry Met Sally']],
#  ['Bruno Kirby', ['When Harry Met Sally']],
#  ['Liv Tyler', ['That Thing You Do']],
#  ['Brooke Langton', ['The Replacements']],
#  ['Gene Hackman', ['Unforgiven', 'The Birdcage', 'The Replacements']],
#  ['Orlando Jones', ['The Replacements']],
#  ['Christian Bale', ['RescueDawn']],
#  ['Zach Grenier', ['RescueDawn', 'Twister']],
#  ['Richard Harris', ['Unforgiven']],
#  ['Clint Eastwood', ['Unforgiven']],
#  ['Takeshi Kitano', ['Johnny Mnemonic']],
#  ['Dina Meyer', ['Johnny Mnemonic']],
#  ['Ice-T', ['Johnny Mnemonic']],
#  ['Halle Berry', ['Cloud Atlas']],
#  ['Jim Broadbent', ['Cloud Atlas']],
#  ['Ian McKellen', ['The Da Vinci Code']],
#  ['Audrey Tautou', ['The Da Vinci Code']],
#  ['Paul Bettany', ['The Da Vinci Code']],
#  ['Natalie Portman', ['V for Vendetta']],
#  ['Stephen Rea', ['V for Vendetta']],
#  ['John Hurt', ['V for Vendetta']],
#  ['Ben Miles', ['Speed Racer', 'Ninja Assassin', 'V for Vendetta']],
#  ['Emile Hirsch', ['Speed Racer']],
#  ['John Goodman', ['Speed Racer']],
#  ['Susan Sarandon', ['Speed Racer']],
#  ['Matthew Fox', ['Speed Racer']],
#  ['Christina Ricci', ['Speed Racer']],
#  ['Rain', ['Speed Racer', 'Ninja Assassin']],
#  ['Naomie Harris', ['Ninja Assassin']],
#  ['Michael Clarke Duncan', ['The Green Mile']],
#  ['David Morse', ['The Green Mile']],
#  ['Sam Rockwell', ['The Green Mile', 'Frost/Nixon']],
#  ['Gary Sinise', ['Apollo 13', 'The Green Mile']],
#  ['Patricia Clarkson', ['The Green Mile']],
#  ['Frank Langella', ['Frost/Nixon']],
#  ['Michael Sheen', ['Frost/Nixon']],
#  ['Oliver Platt', ['Frost/Nixon', 'Bicentennial Man']],
#  ['Danny DeVito', ['Hoffa', "One Flew Over the Cuckoo's Nest"]],
#  ['John C. Reilly', ['Hoffa']],
#  ['Ed Harris', ['Apollo 13']],
#  ['Bill Paxton', ['Twister', 'A League of Their Own', 'Apollo 13']],
#  ['Philip Seymour Hoffman', ['Twister', "Charlie Wilson's War"]],
#  ['Diane Keaton', ["Something's Gotta Give"]],
#  ['Julia Roberts', ["Charlie Wilson's War"]],
#  ['Madonna', ['A League of Their Own']],
#  ['Geena Davis', ['A League of Their Own']],
#  ['Lori Petty', ['A League of Their Own']]]

# %% [markdown]
# ### WITH Clause
# #### Get the First 3 People in the DB ordered descending by the name into a list

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (n:Person)
# WITH n
# ORDER BY n.name DESC
# LIMIT 3
# RETURN collect(n.name)
# Out:
# 1 rows affected.
# [[['Zach Grenier', 'Wil Wheaton', 'Werner Herzog']]]

# %% [markdown]
# #### Get the title of the most recent movie acted by Tom Hanks

# %%
# %%cypher  http://neo4j:engmohamed@127.0.0.1:7474/db/data
# MATCH (p:Person{name:"Tom Hanks"})-[:ACTED_IN]->(m:Movie)
# WITH MAX(m.released) AS max
# MATCH (m:Movie{released:max})
# RETURN m.title,m.released
# Out:
# 1 rows affected.
# [['Cloud Atlas', 2012]]

# %% [markdown]
# # THANK YOU, and GOOD LUCK!
